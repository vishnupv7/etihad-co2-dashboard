# %%
# ✅ Install Streamlit (only once per session)
# !pip install streamlit -q

# ✅ Install Plotly for charts
# !pip install plotly -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 61.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 95.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 6.4 MB/s eta 0:00:00

# %%
import streamlit as st
import pandas as pd
import plotly.express as px

# Load Data
@st.cache_data
def load_data():
    return pd.read_csv("/content/drive/MyDrive/Etihad_CO2_Optimization/data/processed/final_dashboard_dataset.csv")

df = load_data()

# Sidebar Filters
st.sidebar.title("Filter Dashboard")
selected_origin = st.sidebar.selectbox("Select Origin", df["Origin"].unique())
selected_dest = st.sidebar.selectbox("Select Destination", df["Destination"].unique())

filtered_df = df[(df["Origin"] == selected_origin) & (df["Destination"] == selected_dest)]

# Tabs
st.title("Etihad Fuel & CO₂ Optimization Dashboard")
tabs = st.tabs(["Home", "Routes", "Aircraft", "Weather Impact", "ML Insights", "Replay"])

# --- Home Tab ---
with tabs[0]:
    st.header("ESG Overview")
    col1, col2, col3, col4 = st.columns(4)
    col1.metric("Total Flights", len(df))
    col2.metric("Total CO₂ (kg)", f"{df['Adjusted_CO2_kg'].sum():,.0f}")
    col3.metric("Avg Fuel Burn (kg)", f"{df['Fuel_Burn_kg'].mean():,.1f}")
    col4.metric("ESG Match %", f"{df['esg_match_percent'].mean():.1f}%")

    fig = px.line(df, x="FlightDate", y="Adjusted_CO2_kg", title="Monthly CO₂ vs ESG Target")
    st.plotly_chart(fig, use_container_width=True)

# --- Routes Tab ---
with tabs[1]:
    st.header("Route-Level Emissions")
    fig = px.scatter(filtered_df, x="Distance_km", y="Adjusted_CO2_kg",
                     color="Aircraft_Code", hover_data=["Callsign"],
                     title="Route Distance vs CO₂")
    st.plotly_chart(fig, use_container_width=True)
    st.dataframe(filtered_df[["Callsign", "Origin", "Destination", "Fuel_Burn_kg", "Adjusted_CO2_kg", "ASK", "RPK"]])

# --- Aircraft Tab ---
with tabs[2]:
    st.header("Aircraft-Level Analysis")
    fig = px.box(df, x="Aircraft_Code", y="Adjusted_CO2_kg", points="all",
                 title="CO₂ Distribution by Aircraft Type")
    st.plotly_chart(fig, use_container_width=True)

# --- Weather Tab ---
with tabs[3]:
    st.header("Weather Impact on Fuel")
    fig = px.line(df, x="FlightDate", y="Weather_Penalty_Index", color="Aircraft_Code",
                  title="Weather Penalty Index Over Time")
    st.plotly_chart(fig, use_container_width=True)

# --- ML Insights Tab ---
with tabs[4]:

    st.header("Anomaly Detection")

    # Updated x-axis to a valid column
    fig = px.scatter(
        df,
        x="CO2_per_RTK",
        y="esg_match_percent",
        color="SHAP_Top_Feature",
        size="Deviation_km",
        hover_name="Callsign",
        title="ESG Match vs CO₂ per RTK by SHAP Feature",
        labels={
            "CO2_per_RTK": "CO₂ / RTK (g)",
            "esg_match_percent": "ESG Match %",
            "SHAP_Top_Feature": "Top Influencing Feature"
        }
    )
    st.plotly_chart(fig, use_container_width=True)

# --- Replay Tab ---
with tabs[5]:
    st.header("Flight Replay & Simulation")
    flight_id = st.selectbox("Select Flight", df["Callsign"].unique())
    flight_row = df[df["Callsign"] == flight_id]
    st.write(f"**Flight:** {flight_id}")
    st.metric("Original CO₂ (kg)", float(flight_row["Adjusted_CO2_kg"].values[0]))
    st.metric("Suggested CO₂ Saving (kg)", float(flight_row["suggested_reroute_co2_saving_kg"].values[0]))
    st.metric("Reroute Flag", "Yes" if flight_row["recommended_reroute_flag"].values[0] else "No")

# Footer
st.markdown("---")
st.caption("Etihad Airways CO₂ Optimization Dashboard | Streamlit Prototype")
# Out:
# 2025-04-12 21:43:14.639 No runtime found, using MemoryCacheStorageManager
# 2025-04-12 21:43:17.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:17.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:17.471 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:17.472 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:17.475 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:17.477 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:17.478 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:17.479 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:17.711 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:17.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:17.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:17.717 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:17.718 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:17.719 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:18.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:18.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:18.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:18.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:18.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:18.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:18.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:18.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:18.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:18.568 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:18.569 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:18.575 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:18.575 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:18.576 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:18.577 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:18.578 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:18.579 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:18.583 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:18.595 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:18.596 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:18.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:18.612 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:18.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:18.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:29.842 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:30.251 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:31.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:31.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:31.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:31.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:31.966 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:31.971 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:31.995 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:31.998 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:32.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:32.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:32.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:32.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:42.036 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:42.355 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:42.842 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:42.936 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:42.972 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:42.973 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:53.234 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:53.413 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:54.060 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:54.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:54.324 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:43:54.327 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:44:04.740 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:44:05.251 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:44:06.248 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:44:06.426 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:44:06.507 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:44:06.510 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:44:06.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:44:06.971 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:44:06.976 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:44:06.981 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:44:06.983 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:44:06.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:44:07.772 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:44:07.774 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:44:07.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:44:07.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:44:07.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:44:07.779 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:44:07.780 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:44:07.781 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:44:07.782 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:44:07.783 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:44:07.785 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:44:07.786 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:44:07.787 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-12 21:44:07.788 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv('/content/drive/MyDrive/Etihad_CO2_Optimization/data/processed/final_dashboard_dataset.csv')

# Quick test plot
fig = px.scatter(df, x="CO2_per_RTK", y="esg_match_percent", color="SHAP_Top_Feature")
fig.show()
# Out:
# <ipython-input-8-26d47586974c>:4: DtypeWarning:
#
# Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
# Buffered data was truncated after reaching the output size limit.
